# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# %cd /content/drive/'My Drive'/Research/race-car/

# %%
exec(open("rx_torch_to_onnx.py").read())

# %%
drive.flush_and_unmount()
